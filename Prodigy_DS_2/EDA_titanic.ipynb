# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# ### Purpose: This EDA is conducted to explore the data and answer following questions about data:
#
# 1) What factors were associated with higher survival rates?
#
# 2) What were the age and gender distributions among passengers?
#
# 3) What were the average fare prices, and were there differences in fare by embarkation port or class?

# %% [markdown]
# ## Essential Libraries

# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## About Dataset
#
# PassengerId: Unique identifier for each passenger.
#
# Survived: Survival status (0 = No, 1 = Yes).
#
# Pclass: Passenger class (1 = 1st, 2 = 2nd, 3 = 3rd).
#
# Age: Age of the passenger in years.
#
# SibSp: Number of siblings/spouses aboard.
#
# Parch: Number of parents/children aboard.
#
# Fare: Ticket fare paid by the passenger.
#
# Embarked: Port of embarkation (C = Cherbourg, Q = Queenstown, S = Southampton).

# %% [markdown]
# # Overview

# %% [markdown]
# ### Dimensions of Dataset

# %%
print("Shape: ", df.shape)
print("Dimensions: ", df.ndim)
# Out:
# Shape:  (891, 12)
# Dimensions:  2

# %% [markdown]
# ### DataTypes in Dataset

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ### First Few Rows

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Last Few Rows

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ### Columns

# %%
print("---Columns of dataset---")
for col in df.columns:
    print(col)
# Out:
# ---Columns of dataset---
# PassengerId
# Survived
# Pclass
# Name
# Sex
# Age
# SibSp
# Parch
# Ticket
# Fare
# Cabin
# Embarked

# %% [markdown]
# The Purpose of Overivew section was to get basic understanding of the data layout.

# %% [markdown]
# # Basic Statistics about Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### Interpretation
#
# Count: The Total number of passengers in the dataset.
#
# Mean: The Average value of the column.
#
# std: Measures of how spread out values in columns are from the mean.
#
# Min: The smallest value in the dataset for given column.
#
# Max: The largest value in the dataset for given column.
#
# The values 25%, 50%, 75% are quartiles.

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Column Wise record of Missing/Null Values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### Total Missing/Null values in Data

# %%
print("Total count of Null/Missing values:",df.isnull().sum().sum())
# Out:
# Total count of Null/Missing values: 866

# %% [markdown]
# # Handling Missing/Null Data

# %% [markdown]
# ### Numeric Column

# %%
df['Age'] = df['Age'].fillna(df['Age'].mode()[0])
df['Age'] = df['Age'].astype("int64") # --> Correct datatype of age. Most of the time it is integer.

# %% [markdown]
# ### Categorical Column

# %%
def FillNA(columns):
    for col in columns:
        df[col] = df[col].fillna(df[col].mode()[0])

columns = ['Cabin', 'Embarked']
FillNA(columns)

# %% [markdown]
# ### Check Summary
#
# It is essential to check summary to confirm that missing/null data is successfully dealt with.

# %%
df.info()
print("Total count of Null/Missing values:",df.isnull().sum().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    int64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 83.7+ KB
# Total count of Null/Missing values: 0

# %% [markdown]
# Data is now cleaned since all null/missing values have been dealt.

# %% [markdown]
# # Univariate Analysis
#
# Purpose to conduct univariate analysis to grasp the understanding of distribution and variablity of each variable indivdiually.

# %% [markdown]
# ## PassengerID column

# %%
passenger_id_counts = df['PassengerId'].value_counts()

rect = 0.1, 0.1, 0.8, 0.8
fig = plt.figure(figsize=(6, 5))

axes = fig.add_axes(rect)
axes.bar(passenger_id_counts.index, passenger_id_counts.values, color='purple')

axes.set_xlabel("Passenger_id")
axes.set_ylabel("Frequency")
axes.set_title("Distribution of PassengerID Column")
plt.tight_layout()


plt.show()
# Out:
# C:\Users\Waqar\AppData\Local\Temp\ipykernel_15864\706444744.py:12: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# Distribution of PassengerID column is uniform it means PassengerID column is just an Identifier
# there is no need consider this column's normality.

# %% [markdown]
# ## Age Column

# %%
age = df['Age']

plt.figure(figsize=(8, 6))
sns.histplot(df['Age'], bins=20, kde=True, color='blue', edgecolor='black')

plt.title("Distribution of Age")
plt.xlabel("Age")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# Distribution of Age Column is right-skewed meaning most passengers are younger and very few are older stretching the tail toward right side.

# %% [markdown]
# ## Fare Column

# %%
# Boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['Fare'], color='green')
plt.title("Box Plot of Fare")
plt.xlabel("Fare")
plt.show()

# %% [markdown]
# Distribution of Fare Column is right-skewed meaning that most passengers paid relatively low fares only few high paid fares. Outliers (abnormal values) which represent passengers paid high fare to purchase luxury cabins or special tickets etc.

# %% [markdown]
# ## Pclass Column

# %%
# Bar Chart
plt.figure(figsize=(8, 6))

sns.countplot(x='Pclass', data=df, palette='Set2')
plt.title("Distribution of Pclass")
plt.xlabel("Pclass")
plt.ylabel("Frequency")
plt.legend(title="Pclass", labels=['1st Class', '2nd Class', '3rd Class'])


plt.show()
# Out:
# C:\Users\Waqar\AppData\Local\Temp\ipykernel_15864\3492281775.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Pclass', data=df, palette='Set2')

# %% [markdown]
# Th Graph represents the distribution of passenger across different classes. We can see that majority of passengers were in 3rd class followed by
#
# 1st and 2nd class.

# %% [markdown]
# ## Embarked Column

# %%
# Bar plot for Embarked
plt.figure(figsize=(8, 6))
sns.countplot(x='Embarked', data=df, palette='Set1')

plt.title("Distribution of Embarked")
plt.xlabel("Embarked")
plt.ylabel("Frequency")
plt.legend(title='Embarked', labels=['S', 'C', 'Q'])

plt.show()
# Out:
# C:\Users\Waqar\AppData\Local\Temp\ipykernel_15864\715729033.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Embarked', data=df, palette='Set1')

# %% [markdown]
# we can clearly see that most people embarked from port S (Southampton) followed by port C (Cherbourg) and
#
# port Q (Queenstown).

# %% [markdown]
# ## Gender Column

# %%
sns.countplot(data=df, x='Sex', palette="Set3")
plt.title('Gender Distribution of Passengers')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.legend(title='Gender', labels=['male', 'female'])
plt.show()
# Out:
# C:\Users\Waqar\AppData\Local\Temp\ipykernel_15864\3700478112.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Sex', palette="Set3")

# %% [markdown]
# This Graph shows that there were more male passengers than female

# %% [markdown]
# # Multivariate Analysis
#
# It is conducted to study mulitple columns and to understand their relationship with each other.

# %% [markdown]
# ## Class, Gender, and Survival columns

# %%
sns.catplot(x="Pclass", hue="Survived", col="Sex", kind="count", data=df, palette="muted")
plt.suptitle("Survival Rates by Passenger Class and Gender", y=1.05)
plt.show()

# %% [markdown]
# Plot suggests that gender played a crucial role in determining survival on the Titanic, with women having a
#
# higher chance of survival compared to men.

# %% [markdown]
# ## Age, Class, and Survival

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x="Age", y="Pclass", hue="Survived", data=df, palette="viridis", s=100)

plt.title("Survival by Age and Passenger Class")
plt.xlabel("Age")
plt.ylabel("Passenger Class")
plt.gca().invert_yaxis()  # keep 1st class at top

plt.show()

# %% [markdown]
# Thee plot indicates that younger passengers, especially children, had relatively higher survival rates
#
# compared to older age groups.

# %% [markdown]
# ## Age, Gender, and Survival

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="Sex", y="Age", hue="Survived", data=df, palette="Set2")

plt.title("Age Distribution by Gender and Survival")
plt.xlabel("Gender")
plt.ylabel("Age")

plt.show()

# %% [markdown]
# # Visualizing Fare Differences by Embarkation Port

# %%
sns.boxplot(x='Embarked', y='Fare', data=df)
plt.title('Fare Distribution by Embarkation Port')
plt.xlabel('Embarkation Port')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# The graph tells that there was difference in fare based on embarkation port. Port C (Cherbourg) has high fare
#
# followed by port S (Southampton) and port Q (Queenstown)

# %% [markdown]
# # Conclusion:
#
# From above conducted analysis we can answer the questions:
#
# ### 1) What factors were associated with higher survival rates?
#
# Factors associated with higher survival rates are Age, ,gender and Pclass (passenger class).
#
# ### 2) What were the age and gender distributions among the passengers?
#
# Age Distribution: The age distribution might be right-skewed, indicating a higher number of younger passengers.
#
#
# Gender Distribution: The count plot will show the proportion of male and female passengers.
#
# ### 3) What were the average fare prices, and were there differences in fare by embarkation port or class?

# %% [markdown]
# The graph tells that there was difference in fare based on embarkation port. Port C (Cherbourg) has high fare
#
# followed by port S (Southampton) and port Q (Queenstown)
